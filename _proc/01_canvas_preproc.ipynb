# %% [raw]
# ---
# output-file: canvas_preproc.html
# title: Canvas Grades File Preprocessing
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/scott-yj-yang/grades-report/blob/main/grades_report/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# [source](https://github.com/scott-yj-yang/grades-report/blob/main/grades_report/core.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### say_hello
#
# >      say_hello (to)
#
# Say hello to somebody
